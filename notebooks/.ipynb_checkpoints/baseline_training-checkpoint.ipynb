# %% [markdown]
# # Baseline Gaussian Splatting Training
#
# Clean baseline notebook with fixed parameters and no adaptive tuning.

# %%
from pathlib import Path

# ===== PATHS (EDIT THESE) =====
COLMAP_SPARSE_DIR = Path('E:\Thesis\tests\b5740a69-5358-4702-a6d6-1bc57147e0a1\outputs\sparse\0')
IMAGES_DIR = Path('E:\Thesis\tests\b5740a69-5358-4702-a6d6-1bc57147e0a1\images_resized')
OUTPUT_DIR = Path('E:\Thesis\tests\test_jupyter_notebook\outputs\baseline')
RUN_ID = 'baseline_run_001'

# Optional lineage reference to previous run
PREVIOUS_PROJECT_ID = ''
PREVIOUS_RUN_ID = ''
RUN_NOTE = ''

# ===== TRAINING PARAMETERS (EDIT THESE) =====
TRAINING_PARAMS = {
    'max_steps': 15000,
    'batch_size': 1,
    'eval_interval': 1000,
    'save_interval': 2500,
    'densify_from_iter': 500,
    'densify_until_iter': 10000,
    'densification_interval': 100,
    'densify_grad_threshold': 0.0002,
    'opacity_threshold': 0.005,
    'lambda_dssim': 0.2,
}

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print('Configured:', OUTPUT_DIR)
